# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/MyDrive/elsevier/flask_dev'
# %cd $path
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/elsevier/flask_dev

# %%
from google.colab.output import eval_js
vm = eval_js("google.colab.kernel.proxyPort(5000)")
print('App link: ', vm)
# Out:
# App link:  https://jrlc12jlub-496ff2e9c6d22116-5000-colab.googleusercontent.com/

# %%
# !flask --app AnnoApp run
# !flask --app AnnoApp init-db
# Out:
#  * Serving Flask app 'AnnoApp'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [13/Jun/2024 16:17:49] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2024 16:17:50] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2024 16:17:50] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [13/Jun/2024 16:17:54] "GET /create HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2024 16:17:54] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2024 16:17:54] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [13/Jun/2024 16:18:20] "POST /create HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2024 16:18:21] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2024 16:18:21] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [13/Jun/2024 16:18:24] "GET /4/annotate HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2024 16:18:24] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2024 16:18:25] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [13/Jun/2024 16:18:51] "GET /4/update HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2024 16:18:51] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2024 16:18:52] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [13/Jun/2024 16:18:55] "POST /4/update HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2024 16:18:55] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2024 16:18:55] "GET /favicon.ico HTTP/1.1" 404 -
