# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/MyDrive/elsevier/flask_dev'
# %cd $path
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/elsevier/flask_dev

# %%
from google.colab.output import eval_js
vm = eval_js("google.colab.kernel.proxyPort(5000)")
print('List: ', vm)
print('Create: ', vm + 'create')
# Out:
# List:  https://2zk8u8z8shu-496ff2e9c6d22116-5000-colab.googleusercontent.com/
# Create:  https://2zk8u8z8shu-496ff2e9c6d22116-5000-colab.googleusercontent.com/create

# %%
# !flask --app AnnoApp run
# Out:
#  * Serving Flask app 'AnnoApp'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [09/May/2024 22:24:26] "GET /create HTTP/1.1" 200 -
# 127.0.0.1 - - [09/May/2024 22:24:27] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/May/2024 22:24:27] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/May/2024 22:24:28] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/May/2024 22:24:29] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/May/2024 22:24:29] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/May/2024 22:25:44] "GET /14/update HTTP/1.1" 200 -
# 127.0.0.1 - - [09/May/2024 22:25:45] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/May/2024 22:25:45] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/May/2024 22:26:00] "POST /14/update HTTP/1.1" 200 -
# 127.0.0.1 - - [09/May/2024 22:26:00] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/May/2024 22:26:00] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/May/2024 22:26:21] "GET /10/update HTTP/1.1" 200 -
# 127.0.0.1 - - [09/May/2024 22:26:21] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/May/2024 22:26:21] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/May/2024 22:26:31] "POST /10/update HTTP/1.1" 200 -
# 127.0.0.1 - - [09/May/2024 22:26:31] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/May/2024 22:26:32] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/May/2024 22:27:00] "GET /7/update HTTP/1.1" 200 -
# 127.0.0.1 - - [09/May/2024 22:27:01] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [09/May/2024 22:27:01] "GET /favicon.ico HTTP/1.1" 404 -
