# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/MyDrive/elsevier/flask_dev'
# %cd $path
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/elsevier/flask_dev

# %%
from google.colab.output import eval_js
vm = eval_js("google.colab.kernel.proxyPort(5000)")
print('App link: ', vm)
# Out:
# App link:  https://qqrrhybbfp-496ff2e9c6d22116-5000-colab.googleusercontent.com/

# %%
# !flask --app AnnoApp run
# !flask --app AnnoApp init-db
# Out:
#  * Serving Flask app 'AnnoApp'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [17/Jun/2024 22:34:11] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Jun/2024 22:34:12] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Jun/2024 22:34:12] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [17/Jun/2024 22:34:26] "GET /create HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Jun/2024 22:34:27] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Jun/2024 22:34:27] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [17/Jun/2024 22:35:04] "POST /create HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Jun/2024 22:35:04] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Jun/2024 22:35:05] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [17/Jun/2024 22:35:07] "GET /5/annotate HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Jun/2024 22:35:07] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Jun/2024 22:35:08] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [17/Jun/2024 22:37:55] "GET /5/update HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Jun/2024 22:37:56] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Jun/2024 22:37:56] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [17/Jun/2024 22:38:00] "POST /5/update HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Jun/2024 22:38:00] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Jun/2024 22:38:01] "GET /favicon.ico HTTP/1.1" 404 -
