# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/MyDrive/elsevier/flask_dev'
# %cd $path
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/elsevier/flask_dev

# %%
from google.colab.output import eval_js
vm = eval_js("google.colab.kernel.proxyPort(5000)")
print('App link: ', vm)
# Out:
# App link:  https://wl2z2xvp9o8-496ff2e9c6d22116-5000-colab.googleusercontent.com/

# %%
# !flask --app AnnoApp run
# !flask --app AnnoApp init-db
# Out:
#  * Serving Flask app 'AnnoApp'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [13/Jun/2024 22:02:38] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2024 22:02:39] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2024 22:02:39] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [13/Jun/2024 22:02:45] "GET /7/annotate HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2024 22:02:45] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2024 22:02:46] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [13/Jun/2024 22:07:19] "GET /7/update HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2024 22:07:19] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2024 22:07:20] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [13/Jun/2024 22:07:23] "POST /7/update HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2024 22:07:23] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2024 22:07:23] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [13/Jun/2024 22:07:28] "GET /6/annotate HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2024 22:07:28] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2024 22:07:28] "GET /favicon.ico HTTP/1.1" 404 -
# ^C
