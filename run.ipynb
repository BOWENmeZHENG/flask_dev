# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/MyDrive/elsevier/flask_dev'
# %cd $path
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/elsevier/flask_dev

# %%
from google.colab.output import eval_js
vm = eval_js("google.colab.kernel.proxyPort(5000)")
print('App link: ', vm)
# Out:
# App link:  https://swylucfebz-496ff2e9c6d22116-5000-colab.googleusercontent.com/

# %%
# !flask --app AnnoApp run
# !flask --app AnnoApp init-db
# Out:
#  * Serving Flask app 'AnnoApp'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [06/Jun/2024 22:14:01] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2024 22:14:02] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2024 22:14:02] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jun/2024 22:14:04] "GET /5/annotate HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2024 22:14:04] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2024 22:14:05] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jun/2024 22:14:23] "GET /5/update HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2024 22:14:23] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2024 22:14:24] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jun/2024 22:14:30] "POST /5/update HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2024 22:14:30] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2024 22:14:30] "GET /favicon.ico HTTP/1.1" 404 -
