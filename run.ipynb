# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/MyDrive/elsevier/flask_dev'
# %cd $path
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/elsevier/flask_dev

# %%
from google.colab.output import eval_js
vm = eval_js("google.colab.kernel.proxyPort(5000)")
# !npm install https://github.com/tryghost/node-sqlite3/tarball/master
print('List: ', vm)
print('Create: ', vm + 'create')
# Out:
# List:  https://djqxlke22lc-496ff2e9c6d22116-5000-colab.googleusercontent.com/
# Create:  https://djqxlke22lc-496ff2e9c6d22116-5000-colab.googleusercontent.com/create

# %%
# !flask --app AnnoApp run
# !flask --app AnnoApp init-db
# Out:
#  * Serving Flask app 'AnnoApp'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [04/Jun/2024 21:35:05] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jun/2024 21:35:05] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jun/2024 21:35:06] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [04/Jun/2024 21:35:07] "GET /1/annotate HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jun/2024 21:35:07] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jun/2024 21:35:07] "GET /favicon.ico HTTP/1.1" 404 -
